# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df=pd.read_csv("datasets/landcoverFAO.csv")
df
# Out:
#      Unnamed: 0      Domain           Element  \
# 0            25  Land Cover  Area from CCI_LC
# 1            26  Land Cover  Area from CCI_LC
# 2            27  Land Cover  Area from CCI_LC
# 3            28  Land Cover  Area from CCI_LC
# 4            29  Land Cover  Area from CCI_LC
# ..          ...         ...               ...
# 256         481  Land Cover  Area from CCI_LC
# 257         482  Land Cover  Area from CCI_LC
# 258         483  Land Cover  Area from CCI_LC
# 259         484  Land Cover  Area from CCI_LC
# 260         485  Land Cover  Area from CCI_LC
#
#                                                   Item  Year     Unit  \
# 0    Artificial surfaces (including urban and assoc...  1992  1000 ha
# 1    Artificial surfaces (including urban and assoc...  1993  1000 ha
# 2    Artificial surfaces (including urban and assoc...  1994  1000 ha
# 3    Artificial surfaces (including urban and assoc...  1995  1000 ha
# ...

# %%
g = sns.relplot(data=df, x = "Year", y = "Value", kind = "line", hue = "key", row = "station")
